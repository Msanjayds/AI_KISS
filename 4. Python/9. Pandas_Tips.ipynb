# %% [markdown]
# <a href="https://colab.research.google.com/github/Msanjayds/AI_KISS/blob/master/4.%20Python/9.%20Pandas_Tips.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 9. Pandas Tips
# ### a. Select Columns by data type
# ### b. Convert string to Number
# ### c. Find Missing Values
# ### d. Dropping Missing Values
# ### e. Replacing Missing Value
# ### f. Convert continuous data into Categorical

# %%
import pandas as pd

# %%
#Import the data

def load_data():
df = load_data()
  return pd.read_csv('https://raw.githubusercontent.com/Msanjayds/AI_KISS/master/4.%20Python/Data/titan_train.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# ### **a. Select Columns by data type**

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
#Include only int and float columns

df.select_dtypes(include='number').head()
# Out:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500

# %%
#Select Object type columns
df.select_dtypes(include='object').head()
# Out:
#                                                 Name     Sex  ... Cabin Embarked
# 0                            Braund, Mr. Owen Harris    male  ...   NaN        S
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  ...   C85        C
# 2                             Heikkinen, Miss. Laina  female  ...   NaN        S
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  ...  C123        S
# 4                           Allen, Mr. William Henry    male  ...   NaN        S
#
# [5 rows x 5 columns]

# %%
#Include Multiple data types|
df.select_dtypes(include=['int','datetime','object']).head()
# Out:
#    PassengerId  Survived  Pclass  ...            Ticket Cabin  Embarked
# 0            1         0       3  ...         A/5 21171   NaN         S
# 1            2         1       1  ...          PC 17599   C85         C
# 2            3         1       3  ...  STON/O2. 3101282   NaN         S
# 3            4         1       1  ...            113803  C123         S
# 4            5         0       3  ...            373450   NaN         S
#
# [5 rows x 10 columns]

# %%
#Exclude Certain data types
df.select_dtypes(exclude='int').head()
# Out:
#                                                 Name     Sex  ...  Cabin Embarked
# 0                            Braund, Mr. Owen Harris    male  ...    NaN        S
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  ...    C85        C
# 2                             Heikkinen, Miss. Laina  female  ...    NaN        S
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  ...   C123        S
# 4                           Allen, Mr. William Henry    male  ...    NaN        S
#
# [5 rows x 7 columns]

# %% [markdown]
# ### **b. Convert string to Numbers**

# %%
df = pd.DataFrame({'Product':['a','b','c'],
                   'Price': ['10','20','30'],
                   'Sales' : ['20','-','10']
                   })
df
# Out:
#   Product Price Sales
# 0       a    10    20
# 1       b    20     -
# 2       c    30    10

# %%
df.dtypes
# Out:
# Product    object
# Price      object
# Sales      object
# dtype: object

# %%
#Conver price to Integer type
df['Price'] = df['Price'].astype(int)

# %%
df.dtypes
# Out:
# Product    object
# Price       int64
# Sales      object
# dtype: object

# %%
# Use to_numeric method to convert strings with Invalid characters
df['Sales'] = pd.to_numeric(df['Sales'],errors='coerce')
df.dtypes
# Out:
# Product     object
# Price        int64
# Sales      float64
# dtype: object

# %% [markdown]
# ### **C. Find Missing Values**

# %%
df = load_data()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Nullcount by columns
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#total null values
df.isnull().sum().sum()
# Out:
# 866

# %% [markdown]
# ### **D. Dropping Missing Values**

# %%
#Drop the rows if any NaN values are present
print(df.shape)
df_new = df.dropna(axis=0)
print(df_new.shape)
# Out:
# (891, 12)
# (183, 12)

# %%
#Drop the column if any NaN values are present
print(df.shape)
df_new = df.dropna(axis=1)
print(df_new.shape)
# Out:
# (891, 12)
# (891, 9)

# %%
#To drop columns in which more than 10% of values are missing
print(df.shape)
df_new = df.dropna(thresh=len(df) * 0.9 , axis=1)
print(df_new.shape)
# Out:
# (891, 12)
# (891, 10)

# %% [markdown]
# ### **E. Replacing Missing Values**

# %%
#Replace missing values with a scalar value
df.fillna(value=10)
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500    10         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250    10         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500    10         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000    10         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500    10         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500    10         Q
#
# [891 rows x 12 columns]

# %%
# Replace NaN values with the values form previous row

df.fillna(axis=0, method = 'ffill')
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   NaN         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250   C85         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500  C123         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   C50         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500   B42         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500  C148         Q
#
# [891 rows x 12 columns]

# %%
# Replace NaN values with the values form previous column

df.fillna(axis=1, method = 'ffill')
# Out:
#     PassengerId Survived Pclass  ...     Fare  Cabin Embarked
# 0             1        0      3  ...     7.25   7.25        S
# 1             2        1      1  ...  71.2833    C85        C
# 2             3        1      3  ...    7.925  7.925        S
# 3             4        1      1  ...     53.1   C123        S
# 4             5        0      3  ...     8.05   8.05        S
# ..          ...      ...    ...  ...      ...    ...      ...
# 886         887        0      2  ...       13     13        S
# 887         888        1      1  ...       30    B42        S
# 888         889        0      3  ...    23.45  23.45        S
# 889         890        1      1  ...       30   C148        C
# 890         891        0      3  ...     7.75   7.75        Q
#
# [891 rows x 12 columns]

# %%
# Replace with the values in the next row

df.fillna(axis=0, method='bfill')
# Out:
#      PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0              1         0       3  ...   7.2500   C85         S
# 1              2         1       1  ...  71.2833   C85         C
# 2              3         1       3  ...   7.9250  C123         S
# 3              4         1       1  ...  53.1000  C123         S
# 4              5         0       3  ...   8.0500   E46         S
# ..           ...       ...     ...  ...      ...   ...       ...
# 886          887         0       2  ...  13.0000   B42         S
# 887          888         1       1  ...  30.0000   B42         S
# 888          889         0       3  ...  23.4500  C148         S
# 889          890         1       1  ...  30.0000  C148         C
# 890          891         0       3  ...   7.7500   NaN         Q
#
# [891 rows x 12 columns]

# %%
# Replace with the values in the next column

df.fillna(axis=1, method='bfill')
# Out:
#     PassengerId Survived Pclass  ...     Fare Cabin Embarked
# 0             1        0      3  ...     7.25     S        S
# 1             2        1      1  ...  71.2833   C85        C
# 2             3        1      3  ...    7.925     S        S
# 3             4        1      1  ...     53.1  C123        S
# 4             5        0      3  ...     8.05     S        S
# ..          ...      ...    ...  ...      ...   ...      ...
# 886         887        0      2  ...       13     S        S
# 887         888        1      1  ...       30   B42        S
# 888         889        0      3  ...    23.45     S        S
# 889         890        1      1  ...       30  C148        C
# 890         891        0      3  ...     7.75     Q        Q
#
# [891 rows x 12 columns]

# %%
#Replace Nan Values with the mean

df['Age'].fillna(value=df['Age'].median(),inplace=True)
df.head()
# Out:
#    PassengerId  Survived  Pclass  ...     Fare Cabin  Embarked
# 0            1         0       3  ...   7.2500   NaN         S
# 1            2         1       1  ...  71.2833   C85         C
# 2            3         1       3  ...   7.9250   NaN         S
# 3            4         1       1  ...  53.1000  C123         S
# 4            5         0       3  ...   8.0500   NaN         S
#
# [5 rows x 12 columns]

# %% [markdown]
# ## **F. Convert continuous data into Categorical**

# %%
df = load_data()

# %%
df['Age'].head(5)
# Out:
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# Name: Age, dtype: float64

# %%
df.Age.hist();

# %%
import sys

df['AgeGroup'] = pd.cut(df['Age'], bins=[0,13,19,61, sys.maxsize], labels=['<12', 'Teen', 'Adult', 'Older'])

# %%
df[['Age','AgeGroup']]
# Out:
#       Age AgeGroup
# 0    22.0    Adult
# 1    38.0    Adult
# 2    26.0    Adult
# 3    35.0    Adult
# 4    35.0    Adult
# ..    ...      ...
# 886  27.0    Adult
# 887  19.0     Teen
# 888   NaN      NaN
# 889  26.0    Adult
# 890  32.0    Adult
#
# [891 rows x 2 columns]
